# %% [markdown]
# **True_False**

# %%
print(False == 0)
print(True == 1)
# Out:
# True
# True

# %%
print( True + True + True)
print(True + False + False)
# Out:
# 3
# 1

# %% [markdown]
# **and_or_not**

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#showing that none is not equal to 0
print(None == 0)
# Out:
# False

# %%
x = None
y = None
print(x == y)
# Out:
# True

# %%
print(True or False)
# Out:
# True

# %%
print(False and True)
# Out:
# False

# %%
print(not True)
# Out:
# False

# %% [markdown]
# **assert_break_continue_class_def_if_else_elif_del**

# %%
a = [1, 2, 3]
print("The list before deleting any value")
print(a)
# Out:
# The list before deleting any value
# [1, 2, 3]

# %%
del a[1]

# %%
print("the list after deleting 2nd element")
print(a)
# Out:
# the list after deleting 2nd element
# [1, 3]

# %% [markdown]
# **Showing assertionerror**

# %%
assert 5 < 3, "5 is not smaller than 3"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-239f2634efc7> in <module>()
# ----> 1 assert 5 < 3, "5 is not smaller than 3"
#
# AssertionError: 5 is not smaller than 3
